# %%
from nltk.tokenize import RegexpTokenizer
from gensim import corpora, models
from gensim.models import Phrases
from sklearn import decomposition
import pyLDAvis.gensim as gensimvis
import pyLDAvis
import pandas as pd
import numpy as np
import re

# initialize tokenizer and stopwords
en_stop = ['a', 'about', 'above', 'after', 'again', 'against', 'all', 'am', 'an', 'and', 'any', 'are', "aren't", 'as',
           'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', "can't", 'cannot',
           'could', "couldn't", 'did', "didn't", 'do', 'does', "doesn't", 'doing', "don't", 'down', 'during', 'each',
           'few', 'for', 'from', 'further', 'had', "hadn't", 'has', "hasn't", 'have', "haven't", 'having', 'he', "he'd",
           "he'll", "he's", 'her', 'here', "here's", 'hers', 'herself', 'him', 'himself', 'his', 'how', "how's", 'i', "i'd",
           "i'll", "i'm", "i've", 'if', 'in', 'into', 'is', "isn't", 'it', "it's", 'its', 'itself', "let's", 'me', 'more',
           'most', "mustn't", 'my', 'myself', 'no', 'nor', 'not', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'ought',
           'our', 'ours', 'ourselves', 'out', 'over', 'own', 'same', "shan't", 'she', "she'd", "she'll", "she's", 'should',
           "shouldn't", 'so', 'some', 'such', 'than', 'that', "that's", 'the', 'their', 'theirs', 'them', 'themselves', 'then',
           'there', "there's", 'these', 'they', "they'd", "they'll", "they're", "they've", 'this', 'those', 'through', 'to',
           'too', 'under', 'until', 'up', 'very', 'was', "wasn't", 'we', "we'd", "we'll", "we're", "we've", 'were', "weren't",
           'what', "what's", 'when', "when's", 'where', "where's", 'which', 'while', 'who', "who's", 'whom', 'why', "why's",
           'with', "won't", 'would', "wouldn't", 'you', "you'd", "you'll", "you're", "you've", 'your', 'yours', 'yourself',
           'yourselves', 'apos', '&apos;m', '&apos;re', '&apos;s', 's', 'I', 'will', 'go', 'get', '(', ')', '?', ':', ';', ',', '.', '!',
           '/', '"', "'", "...","``", "&apos", "&apos;s", "&apos;&apos;", "-lsb-", "-rsb-", "-lcb-", "-rcb-", "-lrb-", "-rrb-",
           "O&apos;MALLEY", "--"]

stop_chars = ['<', '>']

# get all lemmas between a <story>-</story>-pair:
stories = []
lemma_stories = []
with open('1-2-3_story_test.txt') as infile:
    for line in infile:
        l = line.rstrip()
        if l == "<story>":
            story = []
        elif l == "</story>":
            stories.append(story)
        elif not any(stop_char in l for stop_char in stop_chars):
                story.append(l)


with open('1-2-3_lemma_test.txt') as infile:
    for line in infile:
        l = line.rstrip()
        if l == "<story>":
            story = []
        elif l == "</story>":
            lemma_stories.append(story)
        elif not any(stop_char in l for stop_char in stop_chars):
            if l not in en_stop:
                story.append(l)

# create dictionary and wordcounts corpus:
dictionary = corpora.Dictionary(lemma_stories)
#print(dictionary.token2id)
#dictionary.save("wordcounts.dict")

print(len(dictionary))


# Bag-of-words representation of the stories.
corpus = [dictionary.doc2bow(story) for story in lemma_stories]
#print(corpus)
#corpora.MmCorpus.serialize("corpus.mm", corpus)
print(len(corpus))
print(len(stories))
print(len(lemma_stories))

# create tf.idf model:
tfidf_model = models.TfidfModel(corpus)
#tfidf_model.save("tfidf_model")
tfidf_corpus = tfidf_model[corpus]
print(tfidf_corpus)
print(tfidf_corpus.chunksize)
# corpora.MmCorpus.serialize("tfidf_corpus.mm", tfidf_corpus)
#
# # create topic models:
# LDA
num_topics = 100

lda_model = models.ldamodel.LdaModel(corpus=tfidf_corpus, id2word=dictionary, num_topics=num_topics, update_every=0, chunksize=5000, passes=20)
#lda_model.save("lda_model")
lda_corpus = lda_model[tfidf_corpus]
#corpora.MmCorpus.serialize("lda_corpus.mm", lda_corpus)

print("\nTopics by Latent Dirichlet Allocation model")
topics_found_lda = lda_model.print_topics(num_topics=5, num_words=10)
all_topics = lda_model.print_topics(num_topics=100, num_words=10)

# print(topics_found_lda)



counter = 1

for t in topics_found_lda:
    print("Topic #{} {}".format(counter, t))
    words = re.findall('"([^"]+)"', t[1])
    words = ' '.join(words)
    print(words)
    counter += 1

topics = []
for t in all_topics:
    words = re.findall('"([^"]+)"', t[1])
    words = ' '.join(words)
    topics.append(words)

print(topics)
topics.extend(("Stories with actual words", "Number of subelements in stories with actual words", "Stories with lemmas",
               "Number of subelements in stories with lemmas"))
len(topics)
# Out:
# 28918
# 3174
# 3174
# <gensim.interfaces.TransformedCorpus object at 0x112df66d8>
# None
#
# Topics by Latent Dirichlet Allocation model
# Topic #1 (9, '0.019*"Parade" + 0.018*"parade" + 0.017*"Pasadena" + 0.017*"Rose" + 0.009*"Boulevard" + 0.008*"chilly" + 0.007*"route" + 0.006*"Colorado" + 0.006*"wind" + 0.006*"Santa"')
# Parade parade Pasadena Rose Boulevard chilly route Colorado wind Santa
# Topic #2 (93, '0.005*"kidney" + 0.004*"C" + 0.003*"65" + 0.003*"R" + 0.003*"Hepatitis" + 0.002*"Paraguay" + 0.002*"shark" + 0.002*"attraction" + 0.002*"metrohealth" + 0.002*"stabbing"')
# kidney C 65 R Hepatitis Paraguay shark attraction metrohealth stabbing
# Topic #3 (1, '0.004*"turmoil" + 0.004*"mosque" + 0.003*"France" + 0.003*"Alex" + 0.003*"eat" + 0.002*"Marquardt" + 0.002*"Henry" + 0.002*"yell" + 0.002*"breakfast" + 0.002*"Supreme"')
# turmoil mosque France Alex eat Marquardt Henry yell breakfast Supreme
# Topic #4 (17, '0.002*"Sports" + 0.002*"struggle" + 0.002*"Jamaicans" + 0.002*"best-known" + 0.002*"wake" + 0.002*"export" + 0.002*"conflicted" + 0.002*"humanity" + 0.001*"rear" + 0.001*"&gt;"')
# Sports struggle Jamaicans best-known wake export conflicted humanity rear &gt;
# Topic #5 (89, '0.004*"float" + 0.003*"expressmax" + 0.003*"Road" + 0.002*"ash" + 0.002*"nuggets" + 0.002*"Batman" + 0.002*"grandma" + 0.002*"Superman" + 0.002*"stopper" + 0.001*"original"')
# float expressmax Road ash nuggets Batman grandma Superman stopper original
# ['greeting psychic spectacular expansion ALOHA Sheinelle Senate kickass cheapest theater', 'turmoil mosque France Alex eat Marquardt Henry yell breakfast Supreme', 'lion shoveling spirit Youtube NOOOO squintly Virginia Levine Code subscription', 'Travis Ramadi Blue outbreak Forbes Bell deadly brazen Ed Mosul', 'cutest lottery amopé toll SNL wrinkle unable Adelson cat winning', 'leak Rice knee Brad tylenol Tamir wells workers Workers Kabul', 'segregation inmate unit Pakistan rope Trotter Hayes banquet chicken appointment', 'pain belongings 12th GEICO deliveries arthritis cap reduce Szechwan insurance', 'discretion viewer mature subject Internet Hughesnet matter speed hover University', 'Parade parade Pasadena Rose Boulevard chilly route Colorado wind Santa', 'legal CAITLYN Pennsylvania lawsuit Jenner connected fatal crash dubt suit', 'mouth Biotene lockup dry 65 particularly suffer false tooth soothing', 'Cosby Bill cosby case sexual law defense Sanders fun Bernie', 'TUM acid tum tongue instant stomach source stock Dow Apple', 'lineup burst kitten Spain trevone Quick overdrive shelter fallout Boykin', 'Fleming veterans homeless Salvation Ford seal gurule laundry cost nowadays', 'murder Annette dramatic Arreola carjacking lifelock stranger Kooiman 382 dog', 'Sports struggle Jamaicans best-known wake export conflicted humanity rear &gt;', '15/20 hunting victim Pop anthem extra laxative body duck Gaga', 'Muslims recruitment Qaeda I.S.I.L. recruiting Ramadi hug trump ban terrorist', 'extra consideration tweet captioning fashion Magazine seed crested riddance Bennett', 'pool Burbank hungry bears Vancouver Tattoo nae melon mainland hostage', 'Robin dentures Meade trouble Poligrip Lynn packed lookout Smith marriage', 'rate lock information kit acceptance free insurance 9.95 affordable Penn', '349 Zillow 36 trafficking tornado facetime backyard Mota Gisela armed', 'water morning today week city state The now area weather', 'Ron Ellis volunteer Victorville Afghan Island ha angry diversity Peter', 'mom explain bond Revolution Weekend u-turn countryside unquestionably Express Dunst', 'nurse Hills Beverly household examine celestial teenager Taylor offline Swift', 'Aviv Tel gunman Israel Israeli manhunt attack suspect shooting motive', 'student parks Lolita tweeted fell scaffolding Brookside replacement tower Chen', 'Garth Brooks Carolinas Kennel trop50 Nespresso tuition Malaysia 66 Idaho', 'spectacles cloud Tanya Tech APP onto Bear computing Siri Care', 'Chevy phone pay carrier propaganda packaging offering two-year AT&amp;T Silverado', 'stray fantasy Roy shell reservation Russell galaxy ABC Japanese lag', 'chipotle McCaffrey Combo heisman Arizona Dame Fiesta Bama Watson Notre', 'Lydia upstate sink Vatican aggressively dodgers volatility contender stock debt', 'Jude St. skyline Alisyn architecture logo Dot Org base framing', 'Carson Eliquis bleeding Brown Vegas Las manager campaign Middle Ben', 'Manziel Johnny concussion browns steelers aski Dominican Browns hilltop Lui', 'gun Congress background Obama President Gray violence Munich Germany Freddie', 'www.vitac.com VITAC regime hymn Hollywood campus Bibb urgency Leon hospitalise', 'liquid 97 Alka Seltzer plot GEICO friendly modern whose cold', 'Inthe Barbie familiar periscope slayer Kokomo Hollywood impose allege tenfold', 'Rogers Subaru Wayne Nino pneumonia died investor trapper 82 apartment', 'starbucks opener Benghazi Rousey Jen senator Amazon Ronda Vermont voter', 'callender Marie boyfriend savor MUCINEX pie eling Zicam cough snap', 'American former trail strategy issue growth affect rights agree listen', 'Wabash unit Meyer wish Tamir Indiana eat Max Urban Gilmore', 'rain &lt; storm dry southern El California Tuesday Monday tracking', 'Midwest Kenia fall downstream river emergency crest worst Travis ESPN', 'Eastern Nations Yemen crunch Trinko bburger Sox 174 Horseshoe funny', 'Japan PSH parks park mid echo Borell ethan journalist Hong', 'Fred Carpenter Leslie balloon FIFA Blackwell Mu ...
# 104

# %%
lda_df = pd.DataFrame(columns=range(100))

for i in range(len(stories)):
    doc = lda_corpus[i]
    for top, prob in doc:
        lda_df.set_value(i, top, prob)
print(doc)
with open("Output.txt", "w") as text_file:
    text_file.write("Doc: %s" % (doc))
# Out:
# [(25, 0.26425516979561792), (28, 0.076466293243102654), (47, 0.062660885554882445), (50, 0.023414826679211648), (67, 0.15269501257254828), (79, 0.016806167017510552), (86, 0.063618879898939579), (96, 0.23016389982209157)]

# %%
lda_df
# Out:
#        0          1          2    3    4          5          6         7   \
# 1     NaN        NaN        NaN  NaN  NaN        NaN        NaN       NaN
# 2     NaN        NaN        NaN  NaN  NaN        NaN        NaN       NaN
# 3     NaN        NaN        NaN  NaN  NaN        NaN        NaN       NaN
# 4     NaN        NaN        NaN  NaN  NaN        NaN        NaN       NaN
# 5     NaN        NaN        NaN  NaN  NaN        NaN        NaN       NaN
# 6     NaN        NaN        NaN  NaN  NaN        NaN        NaN       NaN
# 7     NaN        NaN        NaN  NaN  NaN        NaN        NaN       NaN
# 8     NaN        NaN        NaN  NaN  NaN        NaN        NaN       NaN
# 9     NaN        NaN        NaN  NaN  NaN        NaN        NaN       NaN
# 10    NaN        NaN        NaN  NaN  NaN        NaN        NaN       NaN
# 11    NaN  0.0887499        NaN  NaN  NaN        NaN        NaN       NaN
# 12    NaN        NaN        NaN  NaN  NaN        NaN        NaN       NaN
# 13    NaN        NaN        NaN  NaN  NaN        NaN        NaN       NaN
# 14    NaN        NaN        NaN  NaN  NaN        NaN        NaN       NaN
# 15    NaN        NaN        NaN  NaN  NaN        NaN        NaN       NaN
# 16    NaN   0.352322        NaN  NaN  NaN        NaN        NaN       NaN
# 17    NaN        NaN        NaN  NaN  NaN        NaN        NaN       NaN
# 18    NaN        NaN        NaN  NaN  NaN        NaN        NaN       NaN
# 19    NaN  0.0142146        NaN  NaN  NaN        NaN        NaN       NaN
# 20    NaN        NaN        NaN  NaN  NaN        NaN        NaN  0.065866
# 21    NaN        NaN        NaN  NaN  NaN        NaN        NaN       NaN
# 22    NaN        NaN        NaN  NaN  NaN        NaN        NaN       NaN
# 23    NaN        NaN        NaN  NaN  NaN        NaN        NaN       NaN
# 24    NaN        NaN        NaN  NaN  NaN        NaN        NaN       NaN
# 25    NaN        NaN        NaN  NaN  NaN        NaN        NaN       NaN
# 26    NaN        NaN        NaN  NaN  NaN        NaN        NaN       NaN
# 27    NaN        NaN        NaN  NaN  NaN        NaN        NaN       NaN
# 29    NaN        NaN        NaN  NaN  NaN   0.291971        NaN       NaN
# 30    NaN        NaN        NaN  NaN  NaN        NaN        NaN       NaN
# 31    NaN        NaN        NaN  NaN  NaN  0.0131825  0.0191454       NaN
# ...   ...        ...        ...  ...  ...        ...        ...       ...
# 3142  NaN        NaN        NaN  NaN  NaN        NaN        NaN       NaN
# 3144  NaN        NaN        NaN  NaN  NaN        NaN        NaN       NaN
# 3145  NaN        NaN        NaN  NaN  NaN        NaN        NaN       NaN
# 3146  NaN        NaN        NaN  NaN  NaN        NaN        NaN       NaN
# 3147  NaN        NaN        NaN  NaN  NaN  0.0110161        NaN       NaN
# 3148  NaN        NaN        NaN  NaN  NaN   0.021032        NaN       NaN
# 3149  NaN        NaN  0.0164116  NaN  NaN        NaN        NaN       NaN
# 3150  NaN        NaN        NaN  NaN  NaN        NaN   0.125846       NaN
# 3151  NaN        NaN        NaN  NaN  NaN        NaN        NaN       NaN
# 3152  NaN        NaN        NaN  NaN  NaN        NaN        NaN       NaN
# 3153  NaN        NaN        NaN  NaN  NaN        NaN        NaN       NaN
# 3155  NaN        NaN        NaN  NaN  NaN        NaN        NaN       NaN
# 3156  NaN        NaN        NaN  NaN  NaN        NaN        NaN       NaN
# 3157  NaN        NaN        NaN  NaN  NaN        NaN        NaN       NaN
# 3158  NaN        NaN        NaN  NaN  NaN        NaN        NaN       NaN
# 3159  NaN        NaN        NaN  NaN  NaN        NaN        NaN       NaN
# 3160  NaN        NaN        NaN  NaN  NaN        NaN        NaN       NaN
# 3161  NaN        NaN        NaN  NaN  NaN        NaN        NaN       NaN
# 3162  NaN        NaN        NaN  NaN  NaN        NaN        NaN       NaN
# 3163  NaN    0.12569        NaN  NaN  NaN  0.0477659        NaN       NaN
# 3164  NaN        NaN        NaN  NaN  NaN        NaN        NaN       NaN
# 3165  NaN        NaN        NaN  NaN  NaN        NaN        NaN       NaN
# 3166  NaN        NaN        NaN  NaN  NaN        NaN        NaN       NaN
# 3167  NaN        NaN        NaN  NaN  NaN        NaN        NaN       NaN
# 3168  NaN        NaN        NaN  NaN  NaN        NaN        NaN       NaN
# 3169  NaN        NaN        NaN  NaN  NaN        NaN        NaN       NaN
# 3170  NaN        NaN        NaN  NaN  NaN        NaN        NaN       NaN
# 3171  NaN        NaN        NaN  NaN  NaN        NaN        NaN       NaN
# 3172  NaN        NaN        NaN  NaN  NaN  0.0118958        NaN       NaN
# 3173  NaN        NaN        NaN  NaN  NaN        NaN        NaN       NaN
#
#              8          9     ...       90        91   92        93   94   95  \
# 1           NaN        NaN    ...      NaN       NaN  NaN       NaN  NaN  NaN
# 2           NaN        NaN    ...      NaN       NaN  NaN       NaN  NaN  NaN
# 3           NaN        NaN    ...      NaN       NaN  NaN       NaN  NaN  NaN
# 4           NaN        NaN    ...      NaN       NaN  NaN       NaN  NaN  NaN
# 5     0.0399763        NaN    ...      NaN       NaN  NaN       NaN  NaN  NaN
# 6           NaN        NaN    ...      NaN       NaN  NaN       NaN  NaN  NaN
# 7           NaN        NaN    ...      NaN       NaN  NaN       NaN  NaN  NaN
# 8     0.0209594        NaN    ...      NaN       NaN  NaN       NaN  NaN  NaN
# 9           NaN        NaN    ...      NaN       NaN  NaN       NaN  NaN  NaN
# 10          NaN        NaN    ...      NaN       NaN  NaN       NaN  NaN  NaN
# 11          NaN        NaN    ...      NaN       NaN  NaN       NaN  NaN  NaN
# 12          NaN        NaN    ...      NaN       NaN  NaN       NaN  NaN  NaN
# 13          NaN        NaN    ...      NaN       NaN  NaN       NaN  NaN  NaN
# 14    0.0158178  0.0317508    ...      NaN       NaN  NaN       NaN  NaN  NaN
# 15    0.0252975        NaN    ...      NaN       NaN  NaN       NaN  NaN  NaN
# 16          NaN        NaN    ...      NaN       NaN  NaN       NaN  NaN  NaN
# 17          NaN        NaN    ...      NaN       NaN  NaN       NaN  NaN  NaN
# 18          NaN   0.165991    ...      NaN       NaN  NaN       NaN  NaN  NaN
# 19          NaN        NaN    ...      NaN       NaN  NaN       NaN  NaN  NaN
# 20          NaN        NaN    ...      NaN       NaN  NaN       NaN  NaN  NaN
# 21          NaN        NaN    ...      NaN       NaN  NaN       NaN  NaN  NaN
# 22          NaN  0.0159928    ...      NaN       NaN  NaN       NaN  NaN  NaN
# 23          NaN        NaN    ...      NaN       NaN  NaN       NaN  NaN  NaN
# 24          NaN        NaN    ...      NaN       NaN  NaN       NaN  NaN  NaN
# 25          NaN   0.302239    ...      NaN       NaN  NaN       NaN  NaN  NaN
# 26          NaN        NaN    ...      NaN       NaN  NaN       NaN  NaN  NaN
# 27          NaN        NaN    ...      NaN       NaN  NaN       NaN  NaN  NaN
# 29          NaN        NaN    ...      NaN       NaN  NaN       NaN  NaN  NaN
# 30     0.206748        NaN    ...      NaN       NaN  NaN       NaN  NaN  NaN
# 31          NaN        NaN    ...      NaN       NaN  NaN       NaN  NaN  NaN
# ...         ...        ...    ...      ...       ...  ...       ...  ...  ...
# 3142        NaN        NaN    ...      NaN       NaN  NaN       NaN  NaN  NaN
# 3144        NaN        NaN    ...      NaN       NaN  NaN       NaN  NaN  NaN
# 3145        NaN        NaN    ...      NaN       NaN  NaN       NaN  NaN  NaN
# 3146        NaN        NaN    ...      NaN       NaN  NaN       NaN  NaN  NaN
# 3147        NaN        NaN    ...      NaN       NaN  NaN       NaN  NaN  NaN
# 3148   0.223474        NaN    ...      NaN       NaN  NaN       NaN  NaN  NaN
# 3149        NaN        NaN    ...      NaN       NaN  NaN       NaN  NaN  NaN
# 3150        NaN        NaN    ...      NaN       NaN  NaN       NaN  NaN  NaN
# 3151  0.0199571        NaN    ...      NaN       NaN  NaN       NaN  NaN  NaN
# 3152        NaN   0.235982    ...      NaN       NaN  NaN       NaN  NaN  NaN
# 3153        NaN        NaN    ...      NaN       NaN  NaN       NaN  NaN  NaN
# 3155        NaN        NaN    ...      NaN       NaN  NaN       NaN  NaN  NaN
# 3156        NaN        NaN    ...      NaN  0.464899  NaN       NaN  NaN  NaN
# 3157        NaN        NaN    ...      NaN       NaN  NaN       NaN  NaN  NaN
# 3158        NaN        NaN    ...      NaN       NaN  NaN       NaN  NaN  NaN
# 3159        NaN        NaN    ...      NaN       NaN  NaN       NaN  NaN  NaN
# 3160        NaN        NaN    ...      NaN       NaN  NaN       NaN  NaN  NaN
# 3161        NaN        NaN    ...      NaN       NaN  NaN       NaN  NaN  NaN
# 3162        NaN        NaN    ...      NaN       NaN  NaN  0.184966  NaN  NaN
# 3163        NaN        NaN    ...      NaN       NaN  NaN       NaN  NaN  NaN
# 3164        NaN        NaN    ...      NaN       NaN  NaN       NaN  NaN  NaN
# 3165        NaN        NaN    ...      NaN       NaN  NaN  0.208497  NaN  NaN
# 3166        NaN        NaN    ...      NaN       NaN  NaN       NaN  NaN  NaN
# 3167        NaN        NaN    ...      NaN       NaN  NaN       NaN  NaN  NaN
# 3168        NaN  0.0433565    ...      NaN       NaN  NaN       NaN  NaN  NaN
# 3169        NaN        NaN    ...      NaN       NaN  NaN       NaN  NaN  NaN
# 3170        NaN        NaN    ...      NaN       NaN  NaN       NaN  NaN  NaN
# 3171        NaN        NaN    ...      NaN       NaN  NaN       NaN  NaN  NaN
# 3172  0.0176413        NaN    ...      NaN       NaN  NaN       NaN  NaN  NaN
# 3173        NaN        NaN    ...      NaN       NaN  NaN       NaN  NaN  NaN
#
#             96        97         98         99
# 1          NaN       NaN        NaN        NaN
# 2          NaN       NaN        NaN        NaN
# 3          NaN       NaN        NaN        NaN
# 4          NaN       NaN        NaN        NaN
# 5          NaN       NaN  0.0362688        NaN
# 6          NaN       NaN        NaN        NaN
# 7          NaN       NaN        NaN        NaN
# 8          NaN       NaN        NaN        NaN
# 9          NaN       NaN        NaN        NaN
# 10         NaN       NaN        NaN        NaN
# 11         NaN       NaN        NaN        NaN
# 12         NaN       NaN        NaN  0.0250136
# 13         NaN       NaN        NaN        NaN
# 14         NaN       NaN        NaN        NaN
# 15         NaN       NaN        NaN  0.0550411
# 16         NaN       NaN        NaN        NaN
# 17         NaN       NaN        NaN        NaN
# 18         NaN       NaN        NaN        NaN
# 19         NaN       NaN        NaN        NaN
# 20         NaN       NaN  0.0253847        NaN
# 21         NaN       NaN        NaN        NaN
# 22         NaN       NaN        NaN        NaN
# 23         NaN       NaN        NaN        NaN
# 24         NaN       NaN        NaN        NaN
# 25         NaN       NaN        NaN        NaN
# 26         NaN       NaN        NaN        NaN
# 27         NaN       NaN        NaN        NaN
# 29         NaN       NaN        NaN        NaN
# 30         NaN       NaN        NaN        NaN
# 31         NaN       NaN        NaN        NaN
# ...        ...       ...        ...        ...
# 3142       NaN       NaN        NaN        NaN
# 3144       NaN       NaN        NaN        NaN
# 3145       NaN       NaN        NaN        NaN
# 3146       NaN       NaN        NaN        NaN
# 3147       NaN       NaN   0.017654        NaN
# 3148       NaN       NaN        NaN        NaN
# 3149       NaN       NaN        NaN        NaN
# 3150       NaN       NaN        NaN        NaN
# 3151       NaN       NaN        NaN        NaN
# 3152       NaN       NaN        NaN        NaN
# 3153       NaN       NaN        NaN        NaN
# 3155       NaN       NaN        NaN        NaN
# 3156       NaN       NaN        NaN        NaN
# 3157       NaN  0.538195        NaN        NaN
# 3158       NaN       NaN        NaN        NaN
# 3159       NaN       NaN        NaN        NaN
# 3160       NaN       NaN        NaN        NaN
# 3161       NaN       NaN        NaN        NaN
# 3162       NaN       NaN        NaN        NaN
# 3163       NaN       NaN        NaN        NaN
# 3164       NaN       NaN        NaN        NaN
# 3165       NaN       NaN        NaN        NaN
# 3166       NaN       NaN        NaN        NaN
# 3167       NaN       NaN        NaN        NaN
# 3168       NaN       NaN        NaN        NaN
# 3169       NaN       NaN        NaN        NaN
# 3170       NaN       NaN        NaN        NaN
# 3171       NaN       NaN        NaN        NaN
# 3172       NaN       NaN  0.0215665        NaN
# 3173  0.230164       NaN        NaN        NaN
#
# [3088 rows x 100 columns]

# %%
print(stories)
#len(lda_df)
#lda_df[-1] = stories 
# lda_df[-2] = lda_df[-1].apply(lambda x: len(x))
# lda_df[-3] = lemma_stories # Not a good indicator
# lda_df[-4] = lda_df[-3].apply(lambda x: len(x))
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
lda_df.loc[-1] = topics  # adding a row

lda_df.index = lda_df.index + 1  # shifting index

lda_df = lda_df.sort_index() # moving up

lda_df.to_csv('1-2-3_test.csv')
